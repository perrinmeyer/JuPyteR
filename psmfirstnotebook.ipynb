# %%
## Meg's Keynote test IJulia (JuPyteR notebook)

# %%
include("psminclude.jl")
# Out:
# simplot (generic function with 1 method)

# %%
f2,H2,b,a,h,H= cp10hH(1000,0.5,6,96e3,2^12);

# %%
simplot(f2,H2); title("Frequency Response of classic 2nd order Biquad IIR filter")
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# PyObject Text(0.5, 1, 'Frequency Response of classic 2nd order Biquad IIR filter')

# %%
stem(h);title("Impulse response of 2nd order Biquad")
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# PyObject Text(0.5, 1, 'Impulse response of 2nd order Biquad')

# %%
stem(h[100:400]) ; title("Why we can Truncate IIR to make FIR filter")
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# PyObject Text(0.5, 1, 'Why we can Truncate IIR to make FIR filter')
